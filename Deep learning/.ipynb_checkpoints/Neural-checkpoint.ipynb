3 MB/s eta 0:00:04
#    ----------------------------- ---------- 92.0/123.0 MB 9.4 MB/s eta 0:00:04
#    ------------------------------ --------- 93.8/123.0 MB 9.3 MB/s eta 0:00:04
#    ------------------------------- -------- 96.2/123.0 MB 9.4 MB/s eta 0:00:03
#    -------------------------------- ------- 98.6/123.0 MB 9.4 MB/s eta 0:00:03
#    -------------------------------- ------- 100.9/123.0 MB 9.5 MB/s eta 0:00:03
#    --------------------------------- ------ 103.3/123.0 MB 9.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 105.9/123.0 MB 9.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 108.3/123.0 MB 9.6 MB/s eta 0:00:02
#    ------------------------------------ --- 110.9/123.0 MB 9.6 MB/s eta 0:00:02
#    ------------------------------------ --- 113.0/123.0 MB 9.6 MB/s eta 0:00:02
#    ------------------------------------- -- 114.8/123.0 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 116.9/123.0 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 119.0/123.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------  121.4/123.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 123.0/123.0 MB 9.3 MB/s  0:00:13
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 7.4 MB/s  0:00:00
# Downloading torchvision-0.27.0-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------- ----------------- 2.4/4.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 10.3 MB/s  0:00:00
# Downloading torchaudio-2.11.0-cp314-cp314-win_amd64.whl (328 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------------ --------- 1.6/2.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.3 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.3 MB 10.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 9.3 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 3.8 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Installing collected packages: torchaudio, mpmath, sympy, setuptools, networkx, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#   Attempting uninstall: setuptools
#    -------- ------------------------------- 2/9 [sympy]
#    ------------- -------------------------- 3/9 [setuptools]
#     Found existing installation: setuptools 82.0.1
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#     Uninstalling setuptools-82.0.1:
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#       Successfully uninstalled setuptools-82.0.1
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ------------- -------------------------- 3/9 [setuptools]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ---------------------- ----------------- 5/9 [fsspec]
#    ---------------------- ----------------- 5/9 [fsspec]
#    ---------------------- ----------------- 5/9 [fsspec]
#    ---------------------- ----------------- 5/9 [fsspec]
#    ---------------------- ----------------- 5/9 [fsspec]
#    -------------------------- ------------- 6/9 [filelock]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ---------------------------------------- 9/9 [torchvision]
#
# Successfully installed filelock-3.29.0 fsspec-2026.4.0 mpmath-1.3.0 networkx-3.6.1 setuptools-81.0.0 sympy-1.14.0 torch-2.12.0 torchaudio-2.11.0 torchvision-0.27.0
#   WARNING: The script isympy.exe is installed in 'C:\Users\Devendra kachhawa\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\Devendra kachhawa\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\Devendra kachhawa\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import torch 
import torch.nn as nn

# %%
# input 
torch.manual_seed(42)
inputs = torch.tensor([1.0, 2.0, 3.0])

# %%
neuron = nn.Linear(in_features=3, out_features=1)

# %%
output = neuron(inputs)

# %%
output
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
# verify ....... formula
neuron.weight @ inputs + neuron.bias
# Out:
# tensor([1.5244], grad_fn=<AddBackward0>)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5304], requires_grad=True)
